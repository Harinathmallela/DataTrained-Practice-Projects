# %% [markdown]
# # Mushroom Project

# %% [raw]
# The task is to train a model to discriminate hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family.Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and Ivy.

# %% [markdown]
# # Importing Required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
mp=pd.read_csv('Mushroom.csv')
mp.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
mp.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
# Check the data dimension
mp.shape
# Out:
# (8124, 23)

# %% [markdown]
# We have 8124 rows and 23 columns including the target column

# %%
mp.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
#statistical summary
mp.describe().T
# Out:
#                          count unique top  freq
# class                     8124      2   e  4208
# cap-shape                 8124      6   x  3656
# cap-surface               8124      4   y  3244
# cap-color                 8124     10   n  2284
# bruises                   8124      2   f  4748
# odor                      8124      9   n  3528
# gill-attachment           8124      2   f  7914
# gill-spacing              8124      2   c  6812
# gill-size                 8124      2   b  5612
# gill-color                8124     12   b  1728
# stalk-shape               8124      2   t  4608
# stalk-root                8124      5   b  3776
# stalk-surface-above-ring  8124      4   s  5176
# stalk-surface-below-ring  8124      4   s  4936
# stalk-color-above-ring    8124      9   w  4464
# stalk-color-below-ring    8124      9   w  4384
# veil-type                 8124      1   p  8124
# veil-color                8124      4   w  7924
# ring-number               8124      3   o  7488
# ...

# %%
mp['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
mp['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
mp['class'].hist(grid=True)
plt.title('Poisonous vs Edible')
plt.show()

# %% [raw]
# The data is balanced.

# %%
#checking the null values in dataset
mp.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# zero null values.

# %%
plt.figure(figsize=[16,6])
sns.heatmap(mp.isnull())
plt.show()

# %% [markdown]
# The column "veil-type" is P and not contributing to the data so we remove it.

# %%
mp=mp.drop(['veil-type'],axis=1)

# %%
mp.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# ...

# %%
for i in mp.columns:
    mp[i] = LabelEncoder().fit_transform(mp[i])

# %%
mp.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-above-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# ...

# %%
plt.scatter(mp["cap-shape"],mp['cap-surface'],alpha=0.5,c=(0,1,1),edgecolors='b')
plt.title('cap-shape vs cap-surface')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Checking correlation

# %%
corr_mat=mp.corr()

# %%
corr_mat
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize=[22,12])
sns.heatmap(corr_mat,annot=True)
plt.title("Correlarion Matrix")
plt.show()

# %%
corr_matrix=mp.corr()
corr_matrix['class'].sort_values(ascending=False)
# Out:
# class                       1.000000
# gill-size                   0.540024
# population                  0.298686
# habitat                     0.217179
# cap-surface                 0.178446
# spore-print-color           0.171961
# veil-color                  0.145142
# gill-attachment             0.129200
# cap-shape                   0.052951
# cap-color                  -0.031384
# odor                       -0.093552
# stalk-shape                -0.102019
# stalk-color-below-ring     -0.146730
# stalk-color-above-ring     -0.154003
# ring-number                -0.214366
# stalk-surface-below-ring   -0.298801
# stalk-surface-above-ring   -0.334593
# gill-spacing               -0.348387
# stalk-root                 -0.379361
# ring-type                  -0.411771
# bruises                    -0.501530
# gill-color                 -0.530566
# Name: class, dtype: float64

# %% [markdown]
# ## Lets check the data distribution among all the columns

# %%
mp.plot(kind='density',subplots=True, layout=(6,11), sharex=False, legend=False, figsize=[30,20])
plt.show()

# %% [markdown]
# We can see skewness in data for multiple columns, will handle the skewness in further steps.

# %%
#sns.pairplot(mp) #one more example for multi variate analysis
#plt.show

# %% [markdown]
# # Checking Outliers

# %%
mp.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#plotting boxplot for first 11 columns
mp.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#plotting boxplot for first 11 columns
mp.iloc[:,11:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#splitting the independent and target variables in x and y
x=mp.drop('class',axis=1)
y=mp["class"]

# %%
x.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk-surface-above-ring  stalk-surface-below-ring  stalk-color-above-ring  \
# 0                         2                         2                       7
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %%
#checking skewness
mp.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
mp_new=power_transform(x)

mp_new=pd.DataFrame(mp_new,columns=x.columns)

# %%
mp_new.skew()
# Out:
# cap-shape                  -0.205860
# cap-surface                -0.473764
# cap-color                   0.004059
# bruises                     0.342750
# odor                       -0.144660
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                 -0.246738
# stalk-shape                -0.271345
# stalk-root                  0.023182
# stalk-surface-above-ring   -0.438332
# stalk-surface-below-ring   -0.114150
# stalk-color-above-ring     -0.964471
# stalk-color-below-ring     -0.925320
# veil-color                  5.797741
# ring-number                -0.499098
# ring-type                  -0.339232
# spore-print-color           0.018174
# population                 -0.368219
# habitat                     0.123132
# dtype: float64

# %% [markdown]
# # Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
maxAcc=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    LR=LogisticRegression()
    LR.fit(x_train,y_train)
    predlr=LR.predict(x_test)
    acc=accuracy_score(y_test,predlr)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i

print("Best Accuracy is",maxAcc, "n Random_state", maxRS)
# Out:
# Best Accuracy is 0.9585726004922067 n Random_state 21

# %% [markdown]
# We have found best random_state value as 21. We will create our train_test_split  using random_state(21)

# %% [markdown]
# # Creating train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=21)

# %%
from sklearn.linear_model import LogisticRegression

LR=LogisticRegression()
LR.fit(x_train,y_train)
predlr=LR.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.9585726004922067
# [[1217   51]
#  [  50 1120]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1268
#            1       0.96      0.96      0.96      1170
#
#     accuracy                           0.96      2438
#    macro avg       0.96      0.96      0.96      2438
# weighted avg       0.96      0.96      0.96      2438

# %%
from sklearn.tree import DecisionTreeClassifier

DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
preddtc=DTC.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 1.0
# [[1268    0]
#  [   0 1170]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1268
#            1       1.00      1.00      1.00      1170
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
from sklearn.ensemble import RandomForestClassifier

RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predrfc=RFC.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 1.0
# [[1268    0]
#  [   0 1170]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1268
#            1       1.00      1.00      1.00      1170
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
from sklearn.svm import SVC

SVC=SVC()
SVC.fit(x_train,y_train)
predsvc=SVC.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.9897456931911403
# [[1264    4]
#  [  21 1149]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1268
#            1       1.00      0.98      0.99      1170
#
#     accuracy                           0.99      2438
#    macro avg       0.99      0.99      0.99      2438
# weighted avg       0.99      0.99      0.99      2438

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(LR,x,y,cv=5)
print("CVS of LogisticRegression is",scr.mean())
# Out:
# CVS of LogisticRegression is 0.8397181508147025

# %%
scr=cross_val_score(DTC,x,y,cv=5)
print("CVS of DecisionTreeClassifier is",scr.mean())
# Out:
# CVS of DecisionTreeClassifier is 0.9059267904509284

# %%
scr=cross_val_score(RFC,x,y,cv=5)
print("CVS of RandomForestClassifier is",scr.mean())
# Out:
# CVS of RandomForestClassifier is 0.887827283061766

# %%
scr=cross_val_score(SVC,x,y,cv=5)
print("CVS of SVC is",scr.mean())
# Out:
# CVS of SVC is 0.8420306934444864

# %% [markdown]
# Minimum difference in accuracy and cross validation score is for DecisionTreeClassifier. so this is our best model

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
#creating parameters list to pass in GridSearchCV

parameters={"max_depth":np.arange(2,15),
           "criterion":["gini","entropy"]}

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameters,cv=5) #Tuning DecisionTreeClassifier

# %%
GCV.fit(x_train,y_train)

# %%
GCV.best_params_  #printing the best parameters found by GridSearchCV
# Out:
# {'criterion': 'gini', 'max_depth': 8}

# %%
model=DecisionTreeClassifier(criterion= 'gini', max_depth= 8, random_state=21)
model.fit(x_train,y_train)
pred_model=model.predict(x_test)
print(accuracy_score(y_test,pred_model))
# Out:
# 1.0

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(model,"Mushroom_model_new(DTC).pkl")
# Out:
# ['Mushroom_model_new(DTC).pkl']

# %% [markdown]
# # Loading the saved Model

# %%
model_new=joblib.load("Mushroom_model_new(DTC).pkl")

# %%
prediction=model_new.predict(x_test)

# %%
print(accuracy_score(y_test,prediction))
# Out:
# 1.0

# %%
prediction=pd.DataFrame(prediction)   #converting into Data Frame

# %%
prediction
# Out:
#       0
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# ...  ..
# 2433  1
# 2434  0
# 2435  0
# 2436  0
# 2437  1
#
# [2438 rows x 1 columns]

# %%
prediction.to_csv("Mushroom_result.csv") #saving the prediction

# %% [markdown]
# # Conclusion

# %% [raw]
# We performed Exploratory Data Analysis and visualized the impacts of various features on Mushroom dataset.
#
# Decision Tree classifier algorithm with the accuracy of 100% was the best model for predicting the Mushroom is Edible or Poisonous.
